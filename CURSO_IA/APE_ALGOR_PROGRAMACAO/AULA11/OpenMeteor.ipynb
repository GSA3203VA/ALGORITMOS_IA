# %%
import requests

url = "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": -29.69,
    "longitude": -53.81,
    "current": "temperature_2m,relative_humidity_2m,wind_speed_10m",
    "timezone": "America/Sao_Paulo"
}

resposta = requests.get(url, params=params)
dados = resposta.json()

print(dados["current"])
# Out:
# {'time': '2026-06-06T19:15', 'interval': 900, 'temperature_2m': 18.1, 'relative_humidity_2m': 87, 'wind_speed_10m': 3.2}
