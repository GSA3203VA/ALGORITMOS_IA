# %% [markdown]
# #Antes de fechar o VScode use os comandos para atualizar no GitHub
# #Depois de acrescntar as alterações que foi feita no `README.md`, rode no VSCode:

# %%
#.\.venv\Scripts\activate

# %%
'''
#git status
#git add .
#git commit -m "Atualiza arquivos do projeto"
#git push
'''

# %% [markdown]
# #Depois antes de inicial puxe do GitHub Comandos:

# %% [markdown]
# git pull

# %%
#git config --global user.name
#git config --global user.email
