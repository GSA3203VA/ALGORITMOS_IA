# %%
# Lab01
# Revisão básica e rápida sobre o uso do sobre o Pandas

# %%
# inicialmente instalar os pacotes necessários
# caso não tenha instalado o Pandas
# executar a célula [3] retirando o 
# símbolo de comentário: #

# %%
# pesquisar o formato da sintaxe adequado a sua ferramenta
# ! pip install pandas
# ou !pip3 install pandas
# consultar sempre o help do que está usando

# %%
# baixar inicialmente do MCOnf da disciplina a base de dados
# chamada de 'adultos.csv"
# salvar a mesma em diretório a sua escolha
# observar o endereço do diretório ao "ler" esta base de dados

# %%
import pandas as pd
import numpy as np

# %%
base_adulto = pd.read_csv('C:\\Users\\GSA\\Workspace\\ALGORITMOS_IA\\CURSO_IA\\ADEC_ANALISE_DADOS_BALBINOT\\AULA01_ESTATISTICA\\DADOS\\adulto.csv')
#Essa linha tenta carregar um arquivo chamado adulto.csv.

# %%
#lê uma planilha no formato .csv e transforma em uma tabela do Pandas.
base_adulto.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capitalGain  capitalLoss  hoursPerWeek  nativeCountry income
# 0         2174            0            40  United-States  <=50K
# ...

# %%
type(base_adulto.age)
# Out:
# pandas.Series

# %%
type(base_adulto)
# Out:
# pandas.DataFrame

# %% [markdown]
# DataFrame = tabela inteira
# Series = uma coluna da tabela

# %%
base_adulto.loc[0].index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capitalGain', 'capitalLoss', 'hoursPerWeek', 'nativeCountry',
#        'income'],
#       dtype='str')

# %%
base_adulto.age.index

# %%
base_adulto.workclass.index

# %%
len(base_adulto)

# %%
base_adulto.set_index(np.arange(10000,42561),inplace=True)

# %%
base_adulto.set_index(np.arange(10000,42561))

# %%
base_adulto.loc[10001]

# %%
base_adulto.iloc[1]

# %%
base_adulto.age

# %%
base_adulto.occupation

# %%
base_adulto['age']

# %%
base_adulto.iloc[2].loc['education']

# %%
base_adulto.education.loc[10002]

# %%
base_adulto['education'].iloc[2]

# %%
base_adulto.at[10002,'education']
