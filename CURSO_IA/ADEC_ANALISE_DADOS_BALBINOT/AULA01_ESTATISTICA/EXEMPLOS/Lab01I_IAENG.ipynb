# %%
# Lab01
# Revisão básica e rápida sobre o uso do sobre o Numpy, Pandas e o matplotllib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt

# %%
base_adulto = pd.read_csv('C:/Users/abalb/Desktop/adulto.csv')

# %%
base_adulto

# %%
plt.hist(base_adulto.age)
plt.show()

# %%
plt.boxplot(base_adulto.age, vert=False)
plt.show()
