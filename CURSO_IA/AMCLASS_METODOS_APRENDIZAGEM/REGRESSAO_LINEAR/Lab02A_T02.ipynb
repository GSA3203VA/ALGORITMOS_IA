# %% [markdown]
#  LAB 04A
# # TAREFA 02
# # Carregar o conjunto de dados do Titanic usando a biblioteca seaborn

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head(10)

# %%
X = titanic.drop('survived',axis = 1)
Y = titanic['survived']

# %%
X.shape

# %%
Y.shape
